# %% [markdown]
# <a href="https://colab.research.google.com/github/TatyanaKorolevaa/BigData_Seminar2/blob/master/HW_KorolevaT_seminar2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets

# %%
import opendatasets as od
import pandas as pd
import time
from pathlib import Path

# %%
dataset_path = Path('new-york-city-airbnb-open-data', 'AB_NYC_2019.csv')
if not dataset_path.is_file():
    od.download('https://www.kaggle.com/dgomonov/new-york-city-airbnb-open-data')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: tatyanakoroleva111
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/dgomonov/new-york-city-airbnb-open-data
# ...
# 100%|██████████| 2.44M/2.44M [00:00<00:00, 2.70MB/s]

# %%
df = pd.read_csv(dataset_path)
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# вычисление среднего значения
df['price'].mean()
# Out:
# 152.7206871868289

# %%
# вычисление дисперсии
df['price'].var()
# Out:
# 57674.02524696099

# %%
c = df['price']
c
# Out:
# 0        149
# 1        225
# 2        150
# 3         89
# 4         80
#         ...
# 48890     70
# 48891     40
# 48892    115
# 48893     55
# 48894     90
# Name: price, Length: 48895, dtype: int64

# %%
c.to_csv('price.csv')

# %%
df1 = pd.read_csv('price.csv')
df1
# Out:
#        Unnamed: 0  price
# 0               0    149
# 1               1    225
# 2               2    150
# 3               3     89
# 4               4     80
# ...           ...    ...
# 48890       48890     70
# 48891       48891     40
# 48892       48892    115
# 48893       48893     55
# 48894       48894     90
#
# [48895 rows x 2 columns]

# %%
df1['price'].mean()
# Out:
# 152.7206871868289

# %%
df1['price'].var()
# Out:
# 57674.02524696099

# %%
df1['price'].max()
# Out:
# 10000

# %% [markdown]
# ![Скрин.png](data:image/png;base64,...)
